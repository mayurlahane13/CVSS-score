# %%
####Import libraries

import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/18132/Desktop/CA/Final Project/Training Data Set.csv')

# %%
data.head()
# Out:
#    CVSS  Plugin ID  CVE Protocol  Port  \
# 0  10.0      33850  NaN      tcp     0
# 1  10.0      33850  NaN      tcp     0
# 2  10.0      33850  NaN      tcp     0
# 3  10.0      33850  NaN      tcp     0
# 4  10.0      33850  NaN      tcp     0
#
#                                                 Name  \
# 0  Unix Operating System Unsupported Version Dete...
# 1  Unix Operating System Unsupported Version Dete...
# 2  Unix Operating System Unsupported Version Dete...
# 3  Unix Operating System Unsupported Version Dete...
# 4  Unix Operating System Unsupported Version Dete...
#
#                                             Synopsis  \
# 0  The operating system running on the remote hos...
# 1  The operating system running on the remote hos...
# 2  The operating system running on the remote hos...
# 3  The operating system running on the remote hos...
# 4  The operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data.isnull().sum()
# Out:
# CVSS              0
# Plugin ID         0
# CVE            7832
# Protocol          0
# Port              0
# Name              0
# Synopsis          0
# Description       0
# Solution          1
# See Also       3334
# dtype: int64

# %%
del data['See Also']
data.head()
# Out:
#    CVSS  Plugin ID  CVE Protocol  Port  \
# 0  10.0      33850  NaN      tcp     0
# 1  10.0      33850  NaN      tcp     0
# 2  10.0      33850  NaN      tcp     0
# 3  10.0      33850  NaN      tcp     0
# 4  10.0      33850  NaN      tcp     0
#
#                                                 Name  \
# 0  Unix Operating System Unsupported Version Dete...
# 1  Unix Operating System Unsupported Version Dete...
# 2  Unix Operating System Unsupported Version Dete...
# 3  Unix Operating System Unsupported Version Dete...
# 4  Unix Operating System Unsupported Version Dete...
#
#                                             Synopsis  \
# 0  The operating system running on the remote hos...
# 1  The operating system running on the remote hos...
# 2  The operating system running on the remote hos...
# 3  The operating system running on the remote hos...
# 4  The operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
del data['CVE']
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  Unix Operating System Unsupported Version Dete...
# 1  Unix Operating System Unsupported Version Dete...
# 2  Unix Operating System Unsupported Version Dete...
# 3  Unix Operating System Unsupported Version Dete...
# 4  Unix Operating System Unsupported Version Dete...
#
#                                             Synopsis  \
# 0  The operating system running on the remote hos...
# 1  The operating system running on the remote hos...
# 2  The operating system running on the remote hos...
# 3  The operating system running on the remote hos...
# 4  The operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data['Protocol'] = data.Protocol.astype('category')

# %%
data.dtypes
# Out:
# CVSS            float64
# Plugin ID         int64
# Protocol       category
# Port              int64
# Name             object
# Synopsis         object
# Description      object
# Solution         object
# dtype: object

# %%
data['Name'] =data['Name'].str.lower()
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  unix operating system unsupported version dete...
# 1  unix operating system unsupported version dete...
# 2  unix operating system unsupported version dete...
# 3  unix operating system unsupported version dete...
# 4  unix operating system unsupported version dete...
#
#                                             Synopsis  \
# 0  The operating system running on the remote hos...
# 1  The operating system running on the remote hos...
# 2  The operating system running on the remote hos...
# 3  The operating system running on the remote hos...
# 4  The operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data['Synopsis'] =data['Synopsis'].str.lower()
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  unix operating system unsupported version dete...
# 1  unix operating system unsupported version dete...
# 2  unix operating system unsupported version dete...
# 3  unix operating system unsupported version dete...
# 4  unix operating system unsupported version dete...
#
#                                             Synopsis  \
# 0  the operating system running on the remote hos...
# 1  the operating system running on the remote hos...
# 2  the operating system running on the remote hos...
# 3  the operating system running on the remote hos...
# 4  the operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data['Description'] =data['Description'].str.lower()
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  unix operating system unsupported version dete...
# 1  unix operating system unsupported version dete...
# 2  unix operating system unsupported version dete...
# 3  unix operating system unsupported version dete...
# 4  unix operating system unsupported version dete...
#
#                                             Synopsis  \
# 0  the operating system running on the remote hos...
# 1  the operating system running on the remote hos...
# 2  the operating system running on the remote hos...
# 3  the operating system running on the remote hos...
# 4  the operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data['Solution'] =data['Solution'].str.lower()
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  unix operating system unsupported version dete...
# 1  unix operating system unsupported version dete...
# 2  unix operating system unsupported version dete...
# 3  unix operating system unsupported version dete...
# 4  unix operating system unsupported version dete...
#
#                                             Synopsis  \
# 0  the operating system running on the remote hos...
# 1  the operating system running on the remote hos...
# 2  the operating system running on the remote hos...
# 3  the operating system running on the remote hos...
# 4  the operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
from nltk.corpus import stopwords

# %%
x = data['Name'] + ' ' + data['Synopsis'] + ' '+ data['Description']+ ' '+data['Solution']

# %%
x.tail()
# Out:
# 23913    openssl 1.0.2 < 1.0.2t vulnerability the remot...
# 23914    php 5.6.x < 5.6.35 security bypass vulnerabili...
# 23915    openssl 1.0.2 < 1.0.2t vulnerability the remot...
# 23916    openssl 1.0.2 < 1.0.2t vulnerability the remot...
# 23917    ibm spectrum protect server 7.1.x < 7.1.9.100 ...
# dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\18132\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
filtered_words = [word for word in x if word not in stopwords.words('english')]

# %%
len(filtered_words)
# Out:
# 23918

# %%
data.columns = ["Name","Synopsis","Description","Solution"]
data["Name"] = data["Name"].str.lower().str.split()

from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
data['Name'] = data['Name'].apply(lambda x: [item for item in x.split() if item not in stopwords.words('english')])

# %%
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  [unix, operating, system, unsupported, version...
# 1  [unix, operating, system, unsupported, version...
# 2  [unix, operating, system, unsupported, version...
# 3  [unix, operating, system, unsupported, version...
# 4  [unix, operating, system, unsupported, version...
#
#                                             Synopsis  \
# 0  the operating system running on the remote hos...
# 1  the operating system running on the remote hos...
# 2  the operating system running on the remote hos...
# 3  the operating system running on the remote hos...
# 4  the operating system running on the remote hos...
#
#                                          Description  \
# ...

# %%
data['Synopsis'] = data['Synopsis'].apply(lambda x: [item for item in x.split() if item not in stopwords.words('english')])

# %%
data['Description'] = data['Description'].apply(lambda x: [item for item in x.split() if item not in stopwords.words('english')])

# %%
data['Solution'] = data['Solution'].apply(lambda x: [item for item in x.split() if item not in stoplist])

# %%
stoplist = stopwords.words('english')

# %%
data = data[data['Solution'].notna()]

# %%
data.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  [unix, operating, system, unsupported, version...
# 1  [unix, operating, system, unsupported, version...
# 2  [unix, operating, system, unsupported, version...
# 3  [unix, operating, system, unsupported, version...
# 4  [unix, operating, system, unsupported, version...
#
#                                             Synopsis  \
# 0  [operating, system, running, remote, host, lon...
# 1  [operating, system, running, remote, host, lon...
# 2  [operating, system, running, remote, host, lon...
# 3  [operating, system, running, remote, host, lon...
# 4  [operating, system, running, remote, host, lon...
#
#                                          Description  \
# ...

# %%
data1= data.copy()

# %%
data1
# Out:
#        CVSS  Plugin ID Protocol  Port  \
# 0      10.0      33850      tcp     0
# 1      10.0      33850      tcp     0
# 2      10.0      33850      tcp     0
# 3      10.0      33850      tcp     0
# 4      10.0      33850      tcp     0
# ...     ...        ...      ...   ...
# 23913   1.9     128115      tcp   443
# 23914   1.9     122591      tcp   443
# 23915   1.9     128115      tcp    80
# 23916   1.9     128115      tcp   443
# 23917   1.5     118823      tcp  1500
#
#                                                     Name  \
# 0      [unix, operating, system, unsupported, version...
# 1      [unix, operating, system, unsupported, version...
# 2      [unix, operating, system, unsupported, version...
# 3      [unix, operating, system, unsupported, version...
# 4      [unix, operating, system, unsupported, version...
# ...                                                  ...
# 23913         [openssl, 1.0.2, <, 1.0.2t, vulnerability]
# ...

# %%
import re
data1['Name'] = re.sub(r'[^\w\s]','',data1['Name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c7b6a76d7eae> in <module>
#       1 import re
# ----> 2 data1['Name'] = re.sub(r'[^\w\s]','',data1['Name'])
#
# ~\Anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
data1['Name']=data1['Name'].apply(str)

# %%
data1['Synopsis']=data1['Synopsis'].apply(str)

# %%
data1['Description']=data1['Description'].apply(str)

# %%
data1['Solution']=data1['Solution'].apply(str)

# %%
data1.dtypes
# Out:
# CVSS            float64
# Plugin ID         int64
# Protocol       category
# Port              int64
# Name             object
# Synopsis         object
# Description      object
# Solution         object
# dtype: object

# %%
data1['Name'] = data1.apply(lambda row: nltk.word_tokenize(row['Name']), axis=1)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\18132\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
data1['Synopsis'] = data1.apply(lambda row: nltk.word_tokenize(row['Synopsis']), axis=1)

# %%
data1['Description'] = data1.apply(lambda row: nltk.word_tokenize(row['Description']), axis=1)

# %%
data1['Solution'] = data1.apply(lambda row: nltk.word_tokenize(row['Solution']), axis=1)

# %%
data1.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  [[, 'unix, ', ,, 'operating, ', ,, 'system, ',...
# 1  [[, 'unix, ', ,, 'operating, ', ,, 'system, ',...
# 2  [[, 'unix, ', ,, 'operating, ', ,, 'system, ',...
# 3  [[, 'unix, ', ,, 'operating, ', ,, 'system, ',...
# 4  [[, 'unix, ', ,, 'operating, ', ,, 'system, ',...
#
#                                             Synopsis  \
# 0  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 1  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 2  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 3  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 4  [[, 'operating, ', ,, 'system, ', ,, 'running,...
#
#                                          Description  \
# ...

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
data1['Name'] = data1['Name'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.

# %%
data1.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 1  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 2  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 3  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 4  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
#
#                                             Synopsis  \
# 0  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 1  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 2  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 3  [[, 'operating, ', ,, 'system, ', ,, 'running,...
# 4  [[, 'operating, ', ,, 'system, ', ,, 'running,...
#
#                                          Description  \
# ...

# %%
data1['Synopsis'] = data1['Synopsis'].apply(lambda x: [stemmer.stem(y) for y in x])
data1['Description'] = data1['Description'].apply(lambda x: [stemmer.stem(y) for y in x])
data1['Solution'] = data1['Solution'].apply(lambda x: [stemmer.stem(y) for y in x])

# %%
data1.head()
# Out:
#    CVSS  Plugin ID Protocol  Port  \
# 0  10.0      33850      tcp     0
# 1  10.0      33850      tcp     0
# 2  10.0      33850      tcp     0
# 3  10.0      33850      tcp     0
# 4  10.0      33850      tcp     0
#
#                                                 Name  \
# 0  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 1  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 2  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 3  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
# 4  [[, unix, ', ,, oper, ', ,, system, ', ,, unsu...
#
#                                             Synopsis  \
# 0  [[, oper, ', ,, system, ', ,, run, ', ,, remot...
# 1  [[, oper, ', ,, system, ', ,, run, ', ,, remot...
# 2  [[, oper, ', ,, system, ', ,, run, ', ,, remot...
# 3  [[, oper, ', ,, system, ', ,, run, ', ,, remot...
# 4  [[, oper, ', ,, system, ', ,, run, ', ,, remot...
#
#                                          Description  \
# ...
